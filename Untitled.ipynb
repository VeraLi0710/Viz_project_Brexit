# %%
import pandas as pd  
import os  

# Step 1: Define data directory and file names  
data_folder = "data"  # Path to your data folder  
file_names = [  
    "EU_20202021.csv", "EU_20212022.csv",  # European Union datasets  
    "OEU_20202021.csv", "OEU_20212022.csv",  # Other Europe datasets  
    "AF_20202021.csv", "AF_20212022.csv",  # Africa datasets  
    "ASIA_20202021.csv", "ASIA_20212022.csv",  # Asia datasets  
    "AUS_20202021.csv", "AUS_20212022.csv",  # Australasia datasets  
    "SA_20202021.csv", "SA_20212022.csv",  # South America datasets  
    "NA_20202021.csv", "NA_20212022.csv",  # North America datasets  
    "ME_20202021.csv", "ME_20212022.csv",  # Middle East datasets  
]  

# Step 2: Initialize an empty list to store datasets after processing  
all_data = []  

# Step 3: Process each dataset  
for file in file_names:  
    file_path = os.path.join(data_folder, file)  # Construct full file path  
    
    try:  
        # Load the dataset  
        data = pd.read_csv(file_path)  
        print(f"Loaded {file} successfully.")  
    except Exception as e:  
        print(f"Failed to load {file}. Error: {e}")  
        continue  

    # Add the year from the file name  
    if "20202021" in file:  
        data["year"] = "2020/2021"  
    elif "20212022" in file:  
        data["year"] = "2021/2022"  
    
    # Clean column names  
    data.columns = data.columns.str.strip().str.replace(" ", "_").str.lower()  

    # If the dataset is for non-EU regions, select only Total columns and Total rows  
    if "eu" not in file.lower():  
        total_columns = [col for col in data.columns if "total" in col]  
        data = data[["he_provider", "ukprn", "year"] + total_columns]  
    
    # Melt the dataset into long format  
    long_format_data = data.melt(  
        id_vars=["ukprn", "he_provider", "year"],  # Keep unique identifiers  
        var_name="country",                       # Variable name for region or totals  
        value_name="students"                    # Student numbers  
    )  

    # Convert the "students" column to numeric, and replace invalid values with 0  
    long_format_data["students"] = pd.to_numeric(long_format_data["students"], errors="coerce").fillna(0).astype(int)  

    # Retain Total rows for each school and keep "students > 0"  
    cleaned_data = long_format_data[  
        (long_format_data["students"] > 0) | (long_format_data["country"].str.contains("total", case=False))  
    ]  

    # Append processed data  
    all_data.append(cleaned_data)  

# Step 4: Combine all datasets  
final_data = pd.concat(all_data, ignore_index=True)  

# Step 5: Save the combined dataset for further use  
output_file = os.path.join(data_folder, "combined_flow_data_with_totals.csv")  
final_data.to_csv(output_file, index=False)  
print(f"Combined dataset saved to {output_file}")  

# Step 6: Inspect the processed data  
print(final_data.head())
# Out:
# Loaded EU_20202021.csv successfully.
# Loaded EU_20212022.csv successfully.
# Loaded OEU_20202021.csv successfully.
# Loaded OEU_20212022.csv successfully.
# Loaded AF_20202021.csv successfully.
# Loaded AF_20212022.csv successfully.
# Loaded ASIA_20202021.csv successfully.
# Loaded ASIA_20212022.csv successfully.
# Loaded AUS_20202021.csv successfully.
# Loaded AUS_20212022.csv successfully.
# Loaded SA_20202021.csv successfully.
# Loaded SA_20212022.csv successfully.
# Loaded NA_20202021.csv successfully.
# Loaded NA_20212022.csv successfully.
# Loaded ME_20202021.csv successfully.
# Loaded ME_20212022.csv successfully.
# Combined dataset saved to data/combined_flow_data_with_totals.csv
#         ukprn                 he_provider       year  country  students
# 0  10008071.0   AA School of Architecture  2020/2021  austria         5
# 1  10007783.0  The University of Aberdeen  2020/2021  austria        20
# 2  10007849.0          Abertay University  2020/2021  austria         5
# 3  10000291.0    Anglia Ruskin University  2020/2021  austria         5
# 4  10000381.0    Arts Educational Schools  2020/2021  austria         5

# %%
final_data.to_csv("final_data.csv", index=False)

# %%
import pandas as pd  
from geopy.geocoders import Nominatim  
import time  

# 读取原始数据（假设 final_data.csv 包含 he_provider, year, country, total_students 等字段）  
final_data = pd.read_csv("final_data.csv")  

# 初始化 geolocator  
geolocator = Nominatim(user_agent="geoapi")  

def fetch_coordinates(name):  
    """获取地点名称的经纬度"""  
    try:  
        location = geolocator.geocode(name)  
        if location:  
            return location.latitude, location.longitude  
    except Exception as e:  
        print(f"Error fetching coordinates for {name}: {e}")  
    return None, None  

# 获取学校的坐标  
unique_schools = final_data["he_provider"].dropna().unique()  
school_coords = {}  
print("Geocoding schools...")  
for school in unique_schools:  
    lat, lon = fetch_coordinates(school)  
    school_coords[school] = (lat, lon)  
    print(f"Geocoded {school}: {lat}, {lon}")  
    time.sleep(1)  # 避免频繁请求  

# 将学校坐标映射回数据集  
final_data["school_lat"] = final_data["he_provider"].map(lambda x: school_coords.get(x, (None, None))[0])  
final_data["school_lon"] = final_data["he_provider"].map(lambda x: school_coords.get(x, (None, None))[1])  

# 填补缺失值（也可以选择剔除坐标为 None 或 0.0 的数据）  
final_data["school_lat"] = final_data["school_lat"].fillna(0.0)  
final_data["school_lon"] = final_data["school_lon"].fillna(0.0)  

# 这里仅保留落在英国的大致范围（例如经度 -8 到 2，纬度 49 到 61，根据实际情况调整）  
final_data = final_data[  
    (final_data["school_lon"] > -8) & (final_data["school_lon"] < 2) &  
    (final_data["school_lat"] > 49) & (final_data["school_lat"] < 61)  
]  

# 保存带坐标的清理后数据，以便后续调试  
final_data.to_csv("final_data_with_schools_coordinates.csv", index=False)  
print("Saved final_data_with_schools_coordinates.csv")
# Out:
# Geocoding schools...
# Geocoded AA School of Architecture: 9.0130449, 38.7303874
# Geocoded The University of Aberdeen: 57.1639306, -2.100875776271873
# Geocoded Abertay University: 56.4631526, -2.97467889452203
# Geocoded Anglia Ruskin University: 52.20338815, 0.1350225704824107
# Geocoded Arts Educational Schools: 41.3111716, -72.92033833188512
# Geocoded Hult International Business School Ltd: None, None
# Geocoded Aston University: 52.48619045, -1.888468930261664
# Geocoded Bangor University: 53.2300234, -4.13008199555879
# Geocoded Bath Spa University: 51.374858, -2.438714578176041
# Geocoded The University of Bath: 43.674218, -79.3995879
# Geocoded Queen's University Belfast: 54.5842881, -5.933656245995208
# Geocoded BIMM University: 51.4795566, -0.1960698
# Geocoded Birkbeck College: 51.52184485, -0.13021550670673807
# Geocoded The University of Birmingham: 52.435015899999996, -1.947159562796694
# Geocoded The Arts University Bournemouth: 50.7418816, -1.8976735
# Geocoded Bournemouth University: 50.7226231, -1.8641233438403426
# Geocoded BPP University: 51.50537905, -0.22337950306706675
# Geocoded The University of Brighton: None, None
# Geocoded The University of Bristol: 51.50076785, -2.5503106339491204
# Geocoded Brunel University London: 51.5326092, -0.47404989072672915
# Geocoded Buckinghamshire New University: 51.62782205, -0.75343598276741
# Geocoded The University of Buckingham: 52.0244524, -0.7378417452243633
# Geocoded The University of Cambridge: 52.1867003, 0.13650796363903167
# Geocoded Cardiff University: 51.4886911, -3.1794825
# Geocoded The University of Central Lancashire: None, None
# Geocoded University of Chester: 53.200264250000004, -2.8993188621319756
# Geocoded City, University of London: 51.527658200000005, -0.10352447335648303
# Geocoded Courtauld Institute of Art: 51.51149315, -0.11772887582631139
# Geocoded Coventry University: 52.4056372, -1.4997222676795412
# Geocoded Cranfield University: 52.070132900000004, -0.6287023427161589
# Geocoded University of Cumbria: 54.8908157, -2.9223991
# Geocoded De Montfort University: 52.63047175, -1.1402281049813487
# Geocoded University of Derby: 52.937954700000006, -1.497999105195924
# Geocoded The University of Dundee: 56.45796755, -2.9821483135375493
# Geocoded University of Durham: 54.7743725, -1.5766714
# Geocoded The University of East Anglia: 52.62106225, 1.2356187242525833
# Geocoded The University of East London: 51.5075713, 0.0641476
# Geocoded Edinburgh Napier University: 55.93110635, -3.2093902303057424
# Geocoded The University of Edinburgh: 55.948366449999995, -3.185681320007981
# Geocoded The University of Essex: 51.538100850000006, 0.7123974191663069
# Geocoded The University of Exeter: None, None
# Geocoded Glasgow Caledonian University: 55.86746635, -4.250245389417843
# Geocoded The University of Glasgow: 55.873419049999995, -4.289052856658881
# Geocoded University of Gloucestershire: 51.8731804, -2.2239706215311656
# Geocoded Goldsmiths College: 51.473283949999995, -0.03662674755260884
# Geocoded The University of Greenwich: None, None
# Geocoded Guildhall School of Music and Drama: 51.5195225, -0.09237473454516612
# Geocoded Heriot-Watt University: 55.91029585, -3.323447514558347
# Geocoded University of Hertfordshire: 51.75174425, -0.23904979445944738
# Geocoded Imperial College of Science, Technology and Medicine: None, None
# Geocoded Institute of Art - London Limited: None, None
# Geocoded Keele University: 53.0016756, -2.270694218876779
# Geocoded The University of Kent: 51.29508745, 1.0673312821552285
# Geocoded King's College London: 51.50308545, -0.09000212114826903
# Geocoded Kingston University: 51.403073899999995, -0.3032181426130893
# Geocoded The University of Lancaster: 54.009842899999995, -2.787576781958986
# Geocoded Leeds Arts University: 53.808804949999995, -1.5511542789300523
# Geocoded Leeds Beckett University: 53.826144150000005, -1.5933537200236456
# Geocoded The University of Leeds: 53.8430407, -1.58866989583375
# Geocoded The University of Leicester: 52.608264899999995, -1.081000558579433
# Geocoded Liverpool John Moores University: 53.41238439999999, -2.980926958955171
# Geocoded The University of Liverpool: None, None
# Geocoded University of the Arts, London: 51.51768525, -0.11633584389344499
# Geocoded London Business School: 51.5263869, -0.16115218526181216
# Geocoded University of London (Institutes and activities): None, None
# Geocoded City and Guilds of London Art School: None, None
# Geocoded London South Bank University: 51.497703200000004, -0.10180887720295356
# Geocoded London School of Economics and Political Science: 51.51459765, -0.11642199104621423
# Geocoded Loughborough University: 52.763845, -1.237258153986855
# Geocoded The Manchester Metropolitan University: None, None
# Geocoded The University of Manchester: 51.57236815, -1.3114536688023473
# Geocoded Istituto Marangoni Limited: None, None
# Geocoded Middlesex University: 51.65912265, -0.13334151025218616
# Geocoded Newcastle University: 54.98017505, -1.6146802127187847
# Geocoded Northeastern University London: 51.5061905, -0.0715902
# Geocoded The University of Northampton: None, None
# Geocoded University of Northumbria at Newcastle: None, None
# Geocoded University of Nottingham: 52.9387428, -1.2002956927457427
# Geocoded The Nottingham Trent University: 52.95814555, -1.1545502016035694
# Geocoded Oxford Brookes University: 51.755223, -1.2301040395972822
# Geocoded The University of Oxford: 51.765921399999996, -1.2631250075112073
# Geocoded University of Plymouth: 50.3757001, -4.139378575455437
# Geocoded The University of Portsmouth: 50.7938881, -1.0978796
# Geocoded Queen Margaret University, Edinburgh: None, None
# Geocoded Queen Mary University of London: 51.52471385, -0.03931044284306251
# Geocoded The University of Reading: 56.4650368, -2.961257790665237
# Geocoded Regent's University London Limited: None, None
# Geocoded Robert Gordon University: 57.1187364, -2.139306576766816
# Geocoded Royal College of Art: 51.4792809, -0.17045508721674918
# Geocoded Royal College of Music: 51.499477600000006, -0.17710071827517998
# Geocoded Royal Conservatoire of Scotland: 55.86638255, -4.257549087975787
# Geocoded Royal Holloway and Bedford New College: 51.424449550000006, -0.5642561069587715
# Geocoded The University of St. Andrews: 56.3429876, -2.7939691452666806
# Geocoded SOAS University of London: 51.5218979, -0.1288676341954016
# Geocoded The University of Sheffield: 53.3806759, -1.4840345
# Geocoded The University of Southampton: None, None
# Geocoded Staffordshire University: 53.009474749999995, -2.1742692248780635
# Geocoded The University of Stirling: None, None
# Geocoded The University of Strathclyde: 55.8618812, -4.241956565778082
# Geocoded The University of Surrey: 51.24307815, -0.5900544877514773
# Geocoded The University of Sussex: None, None
# Geocoded Swansea University: 51.6080596, -3.9773969
# Geocoded Teesside University: 54.5695266, -1.2355444297582996
# Geocoded University of Wales Trinity Saint David: 52.11313185, -4.075201674546898
# Geocoded University of the Highlands and Islands: None, None
# Geocoded The University of Law: 51.520537000000004, -0.13173725942856418
# Geocoded University College London: 51.52420305, -0.13300072425929543
# Geocoded University of South Wales: 51.5860894, -2.990616
# Geocoded The University of Warwick: 34.072792994445145, -118.16620014398013
# Geocoded University of the West of England, Bristol: 51.50076785, -2.5503106339491204
# Geocoded The University of the West of Scotland: 56.458393599999994, -2.97443952793637
# Geocoded The University of West London: 51.5070185, -0.3028075365414086
# Geocoded The University of Westminster: 51.5168987, -0.14330516808711596
# Geocoded The University of Wolverhampton: 52.5719739, -1.9699298
# Geocoded Wrexham University: 53.0534759, -3.0047901266461725
# Geocoded The University of York: 40.80775585, -73.96161411567529
# Geocoded Aberystwyth University: 52.41554955, -4.065054179671381
# Geocoded AECC University College: 50.7277694, -1.828112718200746
# Geocoded University of Bedfordshire: 51.877732449999996, -0.41005165765760376
# Geocoded Birmingham City University: 52.4822706, -1.8888147987150585
# Geocoded University College Birmingham: 52.481672, -1.9061374380791707
# Geocoded The University of Bolton: 53.57142575, -2.4264782591265446
# Geocoded The University of Bradford: None, None
# Geocoded Canterbury Christ Church University: 51.279182399999996, 1.0903628318027239
# Geocoded The University of Chichester: None, None
# Geocoded Conservatoire for Dance and Drama: None, None
# Geocoded University for the Creative Arts: 51.2162625, -0.8060567021382656
# Geocoded ESCP Europe Business School: None, None
# Geocoded Falmouth University: 50.1489643, -5.07044720681594
# Geocoded Glasgow School of Art: 55.8663077, -4.263900066705968
# Geocoded Hartpury University: None, None
# Geocoded The University of Huddersfield: None, None
# Geocoded The University of Hull: 53.773250649999994, -0.3670415117318655
# Geocoded Institute of Contemporary Music Performance: 51.544477650000005, -0.20232179784067766
# Geocoded Le Cordon Bleu Limited: None, None
# Geocoded The University of Lincoln: None, None
# Geocoded Liverpool Hope University: 53.412914799999996, -2.968953655934631
# Geocoded The Liverpool Institute for Performing Arts: None, None
# Geocoded London Film School Limited: None, None
# Geocoded London Metropolitan University: 51.517382299999994, -0.08834959925816331
# Geocoded London School of Hygiene and Tropical Medicine: 51.5209537, -0.13037143644571766
# Geocoded The Open University: 52.02453775, -0.7092748093945007
# Geocoded Point Blank Music School: None, None
# Geocoded Richmond, The American International University in London: None, None
# Geocoded Roehampton University: 51.4485315, -0.24401071122664614
# Geocoded Royal Academy of Music: 51.52346355, -0.15186193316208124
# Geocoded Royal Northern College of Music: 53.46831975, -2.2372404920394153
# Geocoded The Royal Veterinary College: 51.536826399999995, -0.13361570829139682
# Geocoded SAE Education Limited: None, None
# Geocoded St Mary's University, Twickenham: 51.4371611, -0.3361972
# Geocoded The University of Salford: 53.48650835, -2.2638280058838722
# Geocoded Solent University: 50.9086815, -1.4005162611321633
# Geocoded University of St Mark and St John: None, None
# Geocoded Trinity Laban Conservatoire of Music and Dance: 51.4833429, -0.0069469
# Geocoded The University of Winchester: 51.0626897, -1.3328889649771818
# Geocoded University of Worcester: 42.268662449999994, -71.81183596837596
# Geocoded York St John University: 53.9653269, -1.0806968459195583
# Geocoded ACM Guildford Limited: None, None
# Geocoded Bloomsbury Institute: 51.5116948, -0.117442
# Geocoded Cambridge Arts and Sciences Limited: None, None
# Geocoded Cardiff Metropolitan University: 51.4960947, -3.2127615385866655
# Geocoded Norwich University of the Arts: 52.63062395, 1.295000721697714
# Geocoded Ravensbourne University London: 51.50165815, 0.005704460486348751
# Geocoded The Royal Central School of Speech and Drama: 51.54430755, -0.1741025801918736
# Geocoded Sheffield Hallam University: 53.38172635, -1.462795139475161
# Geocoded University of Suffolk: 52.05192825, 1.1640592563471208
# Geocoded The University of Sunderland: 54.912210900000005, -1.375076642822353
# Geocoded Ulster University: 54.604374, -5.929176
# Geocoded Total: 0.3596739, 32.7525748
# Geocoded Harper Adams University: 52.78025975, -2.4322511730575487
# Geocoded Newbold College: 51.42488, -0.7831118951820274
# Geocoded Edge Hill University: 53.55830545, -2.869269278551262
# Geocoded Met Film School Limited: None, None
# Geocoded Leeds Conservatoire: 53.79752125, -1.5329031748790376
# Geocoded London Studio Centre: 51.5330601, -0.12192404581967217
# Geocoded Royal Academy of Dance: 51.4741106, -0.17563087164898294
# Geocoded St George's, University of London: None, None
# Geocoded Writtle University College: 51.73742625, 0.42823220420249875
# Geocoded The National Film and Television School: 51.7577219, 19.4722279893751
# Geocoded The Ashridge (Bonar Law Memorial) Trust: None, None
# Geocoded Rose Bruford College of Theatre and Performance: None, None
# Geocoded Academy of Live and Recorded Arts: None, None
# Geocoded The University College of Osteopathy: 51.5001841, -0.09459868667582494
# Geocoded CEG UFP Limited: None, None
# Geocoded Christie's Education Limited: None, None
# Geocoded The College of Health Ltd: None, None
# Geocoded Dartington Hall Trust (The): None, None
# Geocoded LAMDA Limited: None, None
# Geocoded Leeds Trinity University: 53.8481537, -1.6450164550572741
# Geocoded The Film Education Training Trust Limited: None, None
# Geocoded Mountview Academy of Theatre Arts: 51.4748412, -0.06974543952990153
# Geocoded Royal Academy of Dramatic Art: 51.5218227, -0.131341071973974
# Geocoded Royal Agricultural University: 51.7080041, -1.9916068233124282
# Geocoded SRUC: 55.94650865, -3.531872942609863
# Geocoded Study Group: 49.8320762, 24.0335223
# Geocoded The Institute of Cancer Research: 51.489775249999994, -0.17461057962416415
# Geocoded Liverpool School of Tropical Medicine: 53.4086917, -2.9694971199140126
# Geocoded London School of Theology: 51.6126733, -0.43141301315347325
# Geocoded Moorlands College: 50.7696154, -1.7746270937618132
# Geocoded Arts University Plymouth: 50.3727993, -4.136978908841802
# Geocoded Birmingham Newman University: 52.4346049, -1.9941518959059625
# Geocoded St Mary's University College: 9.0133597, 38.746977664446895
# Geocoded Stranmillis University College: 54.5725918, -5.937541217711098
# Geocoded University Centre Peterborough: 52.58666425, -0.2325290469496617
# Geocoded Central Film School London: None, None
# Geocoded Escape Studios: 39.11362255, -84.49917040354504
# Geocoded The London Institute of Banking & Finance: None, None
# Geocoded All Nations Christian College: 51.802614899999995, 0.0005026568829514444
# Geocoded West Dean College: 50.906352749999996, -0.7751859971279336
# Geocoded Futureworks: 53.4822728, -2.2533851
# Geocoded The London College: 51.47842195, -0.40834880000000096
# Geocoded Amity Global Education: 27.7433452, 85.3200916
# Geocoded Arden University: 28.59613425, -81.2205422
# Geocoded Bristol Baptist College: 51.4604558, -2.6259498618797954
# Geocoded Bishop Grosseteste University: 53.24382875, -0.5336373782519985
# Geocoded Trinity College Bristol: None, None
# Geocoded The Cambridge Theological Federation: None, None
# Geocoded The College of Integrated Chinese Medicine: None, None
# Geocoded Cliff College: 53.2626335, -1.6279603777731182
# Geocoded The Council of the Inns of Court: None, None
# Geocoded Court Theatre Training Company Ltd: None, None
# Geocoded The Queen's Foundation for Ecumenical Theological Education: None, None
# Geocoded University College of Estate Management: 51.4532231, -0.9638108
# Geocoded ForMission Ltd: None, None
# Geocoded The Institute of Ismaili Studies: None, None
# Geocoded INTO University Partnerships Limited: None, None
# Geocoded The Islamic College: 51.5466571, -0.23099582438186023
# Geocoded Kaplan International Colleges U.K. Limited: None, None
# Geocoded Kaplan Open Learning (Essex) Limited: None, None
# Geocoded KLC School of Design: None, None
# Geocoded LCCM AU UK Limited: None, None
# Geocoded The London School of Architecture: None, None
# Geocoded Luther King House Educational Trust: None, None
# Geocoded The Markfield Institute of Higher Education: None, None
# Geocoded Missio Dei: 41.5230746, -87.9664434
# Geocoded St Mellitus College: 51.4933784, -0.1877566
# Geocoded The Metanoia Institute: None, None
# Geocoded Nazarene Theological College: -27.57149915, 153.25239765864282
# Geocoded Norland College: 51.37591185, -2.373241078981395
# Geocoded ICOM: 54.3754901, 18.6154931
# Geocoded Oxford Business College: 51.7503996, -1.2672203
# Geocoded The Prince's Foundation: 51.5257408, -0.0812994
# Geocoded University Centre Quayside Limited: None, None
# Geocoded Regents Theological College: 52.1135833, -2.3469732297548163
# Geocoded Raindance Educational Services Limited: None, None
# Geocoded The Salvation Army: -33.7829913, 150.67374908975023
# Geocoded Spurgeon's College: 51.4061489, -0.0868106452870342
# Geocoded Waverley Abbey College: None, None
# Geocoded Paris Dauphine International: 48.873858, 2.281325
# Geocoded College of Legal Practice Limited: None, None
# Geocoded Academy of Live Technology Ltd: None, None
# Geocoded The London Interdisciplinary School Ltd: None, None
# Geocoded The Minster Centre: 51.5370822, -0.2039904422819407
# Geocoded MLA College: 13.71746105, 100.54071545295916
# Geocoded Regent College London: 51.55214535, -0.2948120662139506
# Geocoded The Engineering and Design Institute London: 51.4968473, -0.04168663662271428
# Saved final_data_with_schools_coordinates.csv

# %%
import geopandas as gpd  
import os  

# 创建保存 GeoJSON 的目录  
output_dir = "geojson_outputs"  
os.makedirs(output_dir, exist_ok=True)  

# 按学年分割数据并保存为 GeoJSON  
for year in years:  
    data_year = data[data["year"] == year].copy()  
    gdf_year = gpd.GeoDataFrame(  
        data_year,  
        geometry=gpd.points_from_xy(data_year["school_lon"], data_year["school_lat"]),  
        crs="EPSG:4326"  
    )  

    # 修正文件名并设置保存路径  
    output_filename = os.path.join(output_dir, f"schools_{year}.geojson")  
    output_filename = output_filename.replace("/", "_")

    # 保存为 GeoJSON  
    gdf_year.to_file(output_filename, driver="GeoJSON")  
    print(f"Generated {output_filename}")
# Out:
# Generated geojson_outputs_schools_2020_2021.geojson
# Generated geojson_outputs_schools_2021_2022.geojson

# %%
unique_countries = final_data["country"].unique()  
print(unique_countries)
# Out:
# ['austria' 'belgium' 'bulgaria' 'canary_islands' 'croatia'
#  'cyprus_(european_union)' 'cyprus_not_otherwise_specified'
#  'czech_republic' 'denmark' 'estonia' 'finland' 'france' 'germany'
#  'gibraltar' 'greece' 'hungary' 'ireland' 'italy' 'latvia' 'lithuania'
#  'luxembourg' 'malta' 'netherlands' 'poland' 'portugal' 'romania'
#  'réunion' 'slovakia' 'slovenia' 'spain' 'sweden'
#  'european_union_not_otherwise_specified' 'total_european_union' 'total'
#  'albania' 'armenia' 'azerbaijan' 'belarus' 'bosnia_and_herzegovina'
#  'cyprus_(non-european_union)' 'faroe_islands' 'georgia' 'iceland'
#  'kosovo' 'moldova' 'monaco' 'montenegro' 'north_macedonia' 'norway'
#  'russia' 'serbia' 'switzerland' 'turkey' 'ukraine'
#  'europe_not_otherwise_specified' 'total_other_europe' 'total_africa'
#  'total_asia' 'total_australasia' 'total_south_america'
#  'total_north_america' 'total_middle_east']

# %%
import geopandas as gpd  
import pandas as pd  
from geopy.geocoders import Nominatim  
from geopy.exc import GeocoderTimedOut  
import json  

# 初始化地理编码器  
geolocator = Nominatim(user_agent="geojson_creator")  

# 获取国家/区域的中心点函数  
def get_location(country_name):  
    try:  
        location = geolocator.geocode(country_name, timeout=10)  
        if location:  
            return location.latitude, location.longitude  
        else:  
            print(f"无法获取地理位置: {country_name}")  
            return None, None  
    except GeocoderTimedOut:  
        print(f"请求超时: {country_name}")  
        return None, None  

# 你的 unique_countries 列  
unique_countries = [  
    'austria', 'belgium', 'bulgaria', 'canary_islands', 'croatia',  
    'cyprus_(european_union)', 'cyprus_not_otherwise_specified', 'czech_republic',  
    'denmark', 'estonia', 'finland', 'france', 'germany',  
    'gibraltar', 'greece', 'hungary', 'ireland', 'italy', 'latvia', 'lithuania',  
    'luxembourg', 'malta', 'netherlands', 'poland', 'portugal', 'romania',  
    'slovakia', 'slovenia', 'spain', 'sweden', 'norway', 'total_asia', 'total_africa'  
]  

# 创建一个 DataFrame保存地理编码结果  
data = []  
for country in unique_countries:  
    lat, lon = get_location(country)  
    data.append({"country": country, "latitude": lat, "longitude": lon})  

df = pd.DataFrame(data)  

# 异常处理：过滤掉未找到地理位置的区域  
df = df.dropna(subset=["latitude", "longitude"])  

# 将 DataFrame 转为 GeoDataFrame  
gdf = gpd.GeoDataFrame(  
    df,  
    geometry=gpd.points_from_xy(df.longitude, df.latitude),  
    crs="EPSG:4326"  # WGS 84 坐标参考系统  
)  

# 保存为 GeoJSON 文件  
output_filename = "countries_centroids.geojson"  
gdf.to_file(output_filename, driver="GeoJSON")  
print(f"GeoJSON 文件已生成: {output_filename}")
# Out:
# 无法获取地理位置: cyprus_not_otherwise_specified
# GeoJSON 文件已生成: countries_centroids.geojson
